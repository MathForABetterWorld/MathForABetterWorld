# %%
import pandas as pd
from datetime import datetime, timedelta
from json import loads, dumps
import string

df = pd.read_csv("exports.csv")

# %%
df.head()
# Out:
#            Timestamp               Name  \
# 0  1/1/2023 13:05:46      Vincent Faulk
# 1  1/6/2023 15:40:18  JUANITA Chandler
# 2  1/6/2023 15:41:27  JUANITA Chandler
# 3  1/6/2023 15:43:46  JUANITA Chandler
# 4  1/6/2023 15:44:31  JUANITA Chandler
#
#   Weight of pallet (please only put numbers) Rack number:  \
# 0                                        224           XX
# 1                                        507           xx
# 2                                        665           xx
# 3                                        181           xx
# 4                                        713           xx
#
#   What category of product  Client or where the food is going? GBMC Event?  \
# 0              Assorted Dry                         Janet Arce         NaN
# 1                Fruit Cup      McCollouh Homes [Coach Dunkin]         NaN
# 2              Assorted Dry                    Greenmount West         NaN
# ...

# %%
df["Timestamp"] = pd.to_datetime(df['Timestamp'], errors='coerce')

# %%
df2 =  df[df['Timestamp'] >= '2023-07-01']

# %%
df2.head()
# Out:
#                Timestamp          Name  \
# 1302 2023-07-01 15:34:40        Claire
# 1303 2023-07-01 15:35:54        Claire
# 1304 2023-07-01 15:36:28        Claire
# 1305 2023-07-03 12:47:01  Beverly Pinn
# 1306 2023-07-03 12:47:41  Beverly Pinn
#
#      Weight of pallet (please only put numbers) Rack number:  \
# 1302                                     34,061           Xx
# 1303                                        121           Xx
# 1304                                         64           Xx
# 1305                                       2039           Xx
# 1306                                       1951           Xx
#
#      What category of product  Client or where the food is going? GBMC Event?  \
# 1302                Meat [Raw]                         Janet Arce         NaN
# 1303              Assorted Mix                         Janet Arce         NaN
# 1304              Assorted Mix                     BCF Recipient          NaN
# ...

# %%
df2.columns
# Out:
# Index(['Timestamp', 'Name', 'Weight of pallet (please only put numbers)',
#        'Rack number:', 'What category of product ',
#        'Client or where the food is going?', 'GBMC Event?', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
import numpy as np
df2['What category of product '] = df2['What category of product '].replace('Milk', 'Dairy')
df2['What category of product '] = df2['What category of product '].replace('Paper Plates', 'Paper Supplies')
df2['What category of product '] = df2['What category of product '].replace('Juice [Minute Maid]', 'Drinks [Fridge]')
df2['What category of product '] = df2['What category of product '].replace('Bombas Socks', 'Personal Care')
df2['What category of product '] = df2['What category of product '].replace('Dole Juice', 'Dole - Juice')
df2['What category of product '] = df2['What category of product '].replace('Pickles', 'Produce')
df2['What category of product '] = df2['What category of product '].replace('Dole -Juice', 'Dole - Juice')
df2['What category of product '] = df2['What category of product '].replace('Dole- Juice', 'Dole - Juice')
df2['What category of product '] = df2['What category of product '].replace('Dole - juice', 'Dole - Juice')
df2['What category of product '] = df2['What category of product '].replace('Dole- juice', 'Dole - Juice')
df2['What category of product '] = df2['What category of product '].replace('Tea', 'Drinks [Dry]')
df2['What category of product '] = df2['What category of product '].replace('Powerade', 'Drinks [Dry]')
df2['What category of product '] = df2['What category of product '].replace(np.nan, 'Other')
df2['What category of product '] = df2['What category of product '].replace('produce', 'Produce')
df2['What category of product '] = df2['What category of product '].replace('condiments', 'Condiments')
df2['What category of product '] = df2['What category of product '].replace('water', 'Water')
df2['What category of product '] = df2['What category of product '].replace('mixed', 'Assorted Dry')
df2['What category of product '] = df2['What category of product '].replace('Mixed', 'Assorted Dry')
df2['What category of product '] = df2['What category of product '].replace('Dole-Fruit Cups', 'Dole - Fruit Cups')
df2['What category of product '] = df2['What category of product '].replace('Dole fruit cups/tea', 'Dole - Fruit Cups')
df2['What category of product '] = df2['What category of product '].replace('Bread', 'Grains (rice, pasta, etc.)')
df2['What category of product '] = df2['What category of product '].replace('DOLE', 'Dole - Fruit Cups')
df2['What category of product '] = df2['What category of product '].replace('cheese', 'Dairy')
df2['What category of product '] = df2['What category of product '].replace('PLATES', 'Paper Supplies')
df2['What category of product '] = df2['What category of product '].replace('Honest Tea', 'Drinks [Fridge]')
df2['What category of product '] = df2['What category of product '].replace('Clothing', 'Personal Care')
df2['What category of product '] = df2['What category of product '].replace('Plates and yougurt', 'Paper Supplies')
df2['What category of product '] = df2['What category of product '].replace('Meat (Raw)', 'Meat [Raw]')
df2['What category of product '] = df2['What category of product '].replace('BCF Boxes', 'Assorted Dry')
df2['What category of product '] = df2['What category of product '].replace('Corn', 'Produce')
df2['What category of product '] = df2['What category of product '].replace('Dole juice', 'Dole - Juice')
df2['What category of product '] = df2['What category of product '].replace('Plates ', 'Paper Supplies')
df2['What category of product '] = df2['What category of product '].replace('Dole juice ', 'Dole - Juice')
df2['What category of product '] = df2['What category of product '].replace('Food', 'Assorted Dry')
df2['What category of product '] = df2['What category of product '].replace('Mix', 'Assorted Dry')
df2['What category of product '] = df2['What category of product '].replace('Produce and formula', 'Produce')
df2['What category of product '] = df2['What category of product '].replace('Juice', 'Drinks [Fridge]')
df2['What category of product '] = df2['What category of product '].replace('Socks', 'Personal Care')
df2['What category of product '] = df2['What category of product '].replace('Cheese (dairy)', 'Dairy')
df2['What category of product '] = df2['What category of product '].replace('Flour', 'Grains (rice, pasta, etc.)')
df2['What category of product '] = df2['What category of product '].replace('Assorted', 'Assorted Dry')
df2['What category of product '] = df2['What category of product '].replace('Formula', 'Baby Supplies')
df2['What category of product '] = df2['What category of product '].replace('Formula ', 'Baby Supplies')
df2['What category of product '] = df2['What category of product '].replace('Beans', 'Canned Goods')
df2['What category of product '] = df2['What category of product '].replace('bread', 'Grains (rice, pasta, etc.)')
df2['What category of product '] = df2['What category of product '].replace('Eggs', 'Dairy')
df2['What category of product '] = df2['What category of product '].replace('Baby formula', 'Baby Supplies')
df2['What category of product '] = df2['What category of product '].replace('Bomba Socks', 'Personal Care')
df2['What category of product '] = df2['What category of product '].replace('Produce/dairy', 'Produce')
df2['What category of product '] = df2['What category of product '].replace('Bomba socks', 'Personal Care')
df2['What category of product '] = df2['What category of product '].replace('Potatoes ', 'Produce')
df2['What category of product '] = df2['What category of product '].replace('Meat', 'Meat [Raw]')
df2['What category of product '] = df2['What category of product '].replace('Drinks ', 'Drinks [Dry]')
df2['What category of product '] = df2['What category of product '].replace('dole ', 'Dole - Juice')
df2['What category of product '] = df2['What category of product '].replace('Orange Juice ', 'Drinks [Fridge]')
df2['What category of product '] = df2['What category of product '].replace('Beans/protein', 'Canned Goods')
df2['What category of product '] = df2['What category of product '].replace('Minute Maid', 'Drinks [Fridge]')
df2['What category of product '] = df2['What category of product '].replace('Cat Food', 'Pet Supplies')
df2['What category of product '] = df2['What category of product '].replace('Dog Food', 'Pet Supplies')
df2['What category of product '] = df2['What category of product '].replace('Potatoes', 'Produce')
df2['What category of product '] = df2['What category of product '].replace('Frozen Meat', 'Meat [Raw]')
df2['What category of product '] = df2['What category of product '].replace('Frozen Meat ', 'Meat [Raw]')
df2['What category of product '] = df2['What category of product '].replace('Frozen meat ', 'Meat [Raw]')
df2['What category of product '] = df2['What category of product '].replace('assorted dry', 'Assorted Dry')
df2['What category of product '] = df2['What category of product '].replace('Potato/Rice mix', 'Produce')
df2['What category of product '] = df2['What category of product '].replace('Bread and Snacks', 'Snacks')
df2['What category of product '] = df2['What category of product '].replace('baby formula', 'Baby Supplies')
df2['What category of product '] = df2['What category of product '].replace('Gift wrap', 'Other')
df2['What category of product '] = df2['What category of product '].replace('Toilet bowls', 'Household')
df2['What category of product '] = df2['What category of product '].replace('Dole', 'Dole - Fruit Cups')
df2['What category of product '] = df2['What category of product '].replace('Dole - Fruit cups', 'Dole - Fruit Cups')
df2['What category of product '] = df2['What category of product '].replace('Drinks', 'Drinks [Dry]')
df2['What category of product '] = df2['What category of product '].replace('dole', 'Dole - Fruit Cups')
df2['What category of product '] = df2['What category of product '].replace('Toilet bowls ', 'Household')
df2['What category of product '] = df2['What category of product '].replace('Bread and Snacks ', 'Snacks')
# Out:
# <ipython-input-88-70c03c5f4b63>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['What category of product '] = df2['What category of product '].replace('Milk', 'Dairy')
# <ipython-input-88-70c03c5f4b63>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['What category of product '] = df2['What category of product '].replace('Paper Plates', 'Paper Supplies')
# <ipython-input-88-70c03c5f4b63>:4: SettingWithCopyWarning:
# ...

# %%
df2['What category of product '].unique()
# Out:
# array(['Meat [Raw]', 'Assorted Mix', 'Water', 'Drinks [Fridge]', 'Snacks',
#        'Dairy', 'Paper Supplies', 'Dole - Fruit Cups', 'Dole - Juice',
#        'Assorted Fridge', 'Produce', 'Personal Care', 'Frozen [Not Meat]',
#        'Assorted Dry', 'Drinks [Dry]', 'Other', 'Condiments',
#        'Grains (rice, pasta, etc.)', 'Baby Supplies', 'Household',
#        'Danone - Milk', 'Canned Goods', 'Pet Supplies', 'Danone - Yogurt',
#        'Cleaning Supplies'], dtype=object)

# %%
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].str.strip()
df2.head()
# Out:
# <ipython-input-92-588af9b02bfd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Client or where the food is going?"] = df2["Client or where the food is going?"].str.strip()
#                Timestamp          Name  \
# 1302 2023-07-01 15:34:40        Claire
# 1303 2023-07-01 15:35:54        Claire
# 1304 2023-07-01 15:36:28        Claire
# 1305 2023-07-03 12:47:01  Beverly Pinn
# 1306 2023-07-03 12:47:41  Beverly Pinn
#
#      Weight of pallet (please only put numbers) Rack number:  \
# 1302                                     34,061           Xx
# 1303                                        121           Xx
# 1304                                         64           Xx
# ...

# %%
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace(np.nan, 'Other Organization')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('BCF Recipient', 'BCF Curbside - Remington')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Brooklyn Park', 'Brooklyn Homes')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('GBMC BMORE GREEN ANd healthy', 'GBMC')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('GBMC Bmore Green & Healthy', 'GBMC')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('St Ambrose/Oblate Sisters', 'St. Ambrose')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Robin Gibbs/St Ambrose Church/oblate Sisters', 'St. Ambrose')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Meat - Frozen. Corey Windley', 'Corey Windley')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('BCF Curbside', 'BCF Curbside - Remington')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace("Other", 'Other Organization')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('St.Ambrose Mother House', 'St. Ambrose')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('St Ambrose Mother House (nuns)', 'St. Ambrose')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Love&Cornbread', 'Love & Cornbread')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Truck driver', 'Other Organization')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Arce', 'Janet Arce')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Baltimore residents', 'BCF Curbside - Remington')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('THE ISRAELIGHL SCHOOL OF UNIVERSAL PRACTICAL KNOWLEDGE', 'The Israelighl School of Universal Practical Knowledge')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Delivery', 'Other Organization')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Mauricio', 'Farmlink [Mauricio]')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Christy Keppell', 'Christy Keppel')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Kristy Keppel', 'Christy Keppel')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('BCF (not curbside)', 'BCF [Non Curbside] - Remington')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Greg wilkes', 'Greg Wilkes')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Manna Bible Baptist Church', 'Manor Bible Outreach')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Manner Bible Baptist church', 'Manor Bible Outreach')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Manna Bible', 'Manor Bible Outreach')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Manna Baptist Church', 'Manor Bible Outreach')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Christy', 'Christy Keppel')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Brooklyn', 'Brooklyn Homes')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Weekend Backpacks (Christy)', 'Weekend Backpacks')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Power of faith ministry (Myra McDonald)', 'Power of Faith Ministry')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Homeless Man', 'Other Organization')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Crystal Shaw', 'Crystal [Kingdom Worship Center]')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Brooklyn homes', 'Brooklyn Homes')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Brooklyn Home', 'Brooklyn Homes')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('brooklyn homes', 'Brooklyn Homes')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Boys and Girls', 'Boys and Girls Club')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Charm City companions', 'Charm City Companions')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Charm City (Pedro)', 'Pedro')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace("Boys & Girls' club - Alicia", 'Boys and Girls Club')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Manor Bible', 'Manor Bible Outreach')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Kingdom Workship Center', 'Crystal [Kingdom Worship Center]')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Mack Lewis', 'Mack Lewis Foundation')
# Out:
# <ipython-input-126-514d32d5ae85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace(np.nan, 'Other Organization')
# <ipython-input-126-514d32d5ae85>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('BCF Recipient', 'BCF Curbside - Remington')
# <ipython-input-126-514d32d5ae85>:3: SettingWithCopyWarning:
# ...

# %%
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Hilem', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Corey Windley', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Robin Gibbs', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Roxanne', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Harris', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Greg Wilkes', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Wanda Best', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Christy Keppel', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Briscoe', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Sarah', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Sunita', 'Sunita [Delivery]')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Gail', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Elain', 'Individual')
df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Tammy', 'Individual')
# Out:
# <ipython-input-161-e41d66a9036a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Hilem', 'Individual')
# <ipython-input-161-e41d66a9036a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Client or where the food is going?"] = df2["Client or where the food is going?"].replace('Corey Windley', 'Individual')
# <ipython-input-161-e41d66a9036a>:3: SettingWithCopyWarning:
# ...

# %%
df2["Client or where the food is going?"].unique()
# Out:
# array(['Janet Arce', 'BCF Curbside - Remington', 'Brooklyn Homes',
#        'Midwest Food Bank [Manchester, CT]', 'GBMC BMore Green & Healthy',
#        'Pedro', 'Love & Cornbread', 'Individual', 'Mack Lewis Foundation',
#        'Crystal [Kingdom Worship Center]', 'St. Ambrose', 'BCHD',
#        'Baltimore Youth Arts', 'Other Organization', 'Sandtown',
#        'Sherman Family Foundation', 'Boys and Girls Club',
#        'Farmlink [Mauricio]', 'Operation Impact', 'Sunita [Delivery]',
#        'The Israelighl School of Universal Practical Knowledge',
#        'Celestial Manna @SPEP', 'Greater Mount Holly CDC',
#        'Manor Bible Outreach', 'Morgan State University',
#        'BCF [Non Curbside] - Remington',
#        'Woodhome Elementary Middle School', 'MICA',
#        'New Beginnings Center Church', 'Celestial Manna',
#        'Fort Worthington', 'Douglas Homes', 'Haven for the Homeless',
#        'ISUPK MA', 'Barb CASA', 'Share Baby', 'Weekend Backpacks',
# ...

# %%
df2["Name"] = df2["Name"].str.strip()
# Out:
# <ipython-input-131-1337ad1576ae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Name"] = df2["Name"].str.strip()

# %%
df2["Name"] = df2["Name"].replace('M. Safire Windley', 'Safire Windley')
df2["Name"] = df2["Name"].replace('Robin Gibbs/St Ambrose Catholic Church/Oblate Sisters', 'Robin Gibbs')
df2["Name"] = df2["Name"].replace('Robin Gibbs/St Ambrose Church/ Oblate Sisters', 'Robin Gibbs')
df2["Name"] = df2["Name"].replace('Safire W', 'Safire Windley')
df2["Name"] = df2["Name"].replace('Barb Zadek', 'Barbara Zadek')
df2["Name"] = df2["Name"].replace('Pedro (8/5)', 'Pedro')
df2["Name"] = df2["Name"].replace('Arce (8/6)', 'Janet Arce')
df2["Name"] = df2["Name"].replace('St.Ambrose Mother House', 'Robin Gibbs')
df2["Name"] = df2["Name"].replace('Nina', 'Nina Early')
df2["Name"] = df2["Name"].replace('SAFIRE W', 'Safire Windley')
df2["Name"] = df2["Name"].replace('SAFIRE', 'Safire Windley')
df2["Name"] = df2["Name"].replace('Sunita', 'Sunita Pathik')
df2["Name"] = df2["Name"].replace('Sunita pathik', 'Sunita Pathik')
df2["Name"] = df2["Name"].replace(np.nan, 'Other')
df2["Name"] = df2["Name"].replace('lorissa m', 'Lorissa M')
df2["Name"] = df2["Name"].replace('Aaron Oldenburg 8/19/23', 'Aaron Oldenburg')
df2["Name"] = df2["Name"].replace('Arce', 'Janet Arce')
df2["Name"] = df2["Name"].replace('Beverly Pinnn', 'Beverly Pinn')
df2["Name"] = df2["Name"].replace('Peter campbell', 'Peter Campbell')
df2["Name"] = df2["Name"].replace('Kingdom Worship center', 'Kingdom Worship Center')
df2["Name"] = df2["Name"].replace('Kingdom worship center', 'Kingdom Worship Center')
df2["Name"] = df2["Name"].replace('Chi chi', 'Chi Chi')
df2["Name"] = df2["Name"].replace('Xinyue gu', 'Xinyue Gu')
df2["Name"] = df2["Name"].replace('XinyuebGu', 'Xinyue Gu')
df2["Name"] = df2["Name"].replace('Xinyue', 'Xinyue Gu')
df2["Name"] = df2["Name"].replace('XX', 'Other')
df2["Name"] = df2["Name"].replace('chi    9/9/23', 'Chi Chi')
df2["Name"] = df2["Name"].replace('chi    9/28/23', 'Chi Chi')
df2["Name"] = df2["Name"].replace('chi   9/28/23', 'Chi Chi')
df2["Name"] = df2["Name"].replace('chi      9/28/23', 'Chi Chi')
df2["Name"] = df2["Name"].replace('chi      9/29/23', 'Chi Chi')
df2["Name"] = df2["Name"].replace('Haven for the Homeless - Bria Evans', 'Bria Evans')
df2["Name"] = df2["Name"].replace('chi    9/8/23', 'Chi Chi')
df2["Name"] = df2["Name"].replace('chi chi', 'Chi Chi')
df2["Name"] = df2["Name"].replace('CHI CHI', 'Chi Chi')
df2["Name"] = df2["Name"].replace('Chi', 'Chi Chi')
df2["Name"] = df2["Name"].replace('Aaron Oldenburg 10/14/23', 'Aaron Oldenburg')
df2["Name"] = df2["Name"].replace('Aaron Oldenburg 10/13/23', 'Aaron Oldenburg')
df2["Name"] = df2["Name"].replace('Crustal shaw', 'Crystal Shaw')
df2["Name"] = df2["Name"].replace('Crystal shaw', 'Crystal Shaw')
df2["Name"] = df2["Name"].replace('CHI', 'Chi Chi')
df2["Name"] = df2["Name"].replace('chi', 'Chi Chi')
df2["Name"] = df2["Name"].replace('marci', 'Marci')
df2["Name"] = df2["Name"].replace('Nathaniel', 'Nathaniel Sheps')
df2["Name"] = df2["Name"].replace('Eve', 'Evelyn')
# Out:
# <ipython-input-163-2c2637426647>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Name"] = df2["Name"].replace('M. Safire Windley', 'Safire Windley')
# <ipython-input-163-2c2637426647>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Name"] = df2["Name"].replace('Robin Gibbs/St Ambrose Catholic Church/Oblate Sisters', 'Robin Gibbs')
# <ipython-input-163-2c2637426647>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df2["Name"].unique()
# Out:
# array(['Claire', 'Beverly Pinn', 'Safire Windley', 'Barbara Zadek', 'JC',
#        'Robin Gibbs', 'Denise BCHD', 'Evelyn', 'Other', 'Opey', 'Pedro',
#        'Janet Arce', 'Sandtown', 'Nina Early', 'Sunita Pathik',
#        'Kevin James', 'Aaron Oldenburg', 'Zoe', 'Lorissa M',
#        'Tram Nguyen', 'Lykinda Camper', 'Ronald Robinson',
#        'Bryant martin', 'Bryant Martin', 'Jaden Scott', 'Peter Campbell',
#        'Mia Callaway', 'Denise Rivers', 'Karen', 'Adriana Hill',
#        'Waldo Alvarez', 'Kate', 'John Dorsey', 'Kingdom Worship Center',
#        'Mary Jo Gary', 'Chi Chi', 'Xinyue Gu', 'Charmika Burton',
#        'Bria Evans', 'Kelly', 'Rochelle Clunie', 'Emily', 'Camille',
#        'Crystal Shaw', 'Marci', 'Connie Huang', 'Shaan',
#        'Nathaniel Sheps', 'Adira'], dtype=object)

# %%
df2.columns
# Out:
# Index(['Timestamp', 'Name', 'Weight of pallet (please only put numbers)',
#        'Rack number:', 'What category of product ',
#        'Client or where the food is going?', 'GBMC Event?', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
print('[')
for i, row in df2.iterrows():
    print('\t{')
    print('\t\tdate: ' + '"' + str(row['Timestamp']) + '"' + ',')
    print('\t\tname: ' + '"'+ string.capwords(row['Name']) + '"' +',')
    print('\t\tweight: ' + str(row['Weight of pallet (please only put numbers)']) +',')
    print('\t\tcategory: ' + '"'+ string.capwords(row['What category of product ']) + '"' +',')
    print('\t\tlocation: ' + '"'+ string.capwords(row['Client or where the food is going?']) + '"')
    print('\t},')
print(']')

# %%
df3 = pd.read_csv("imports.csv")
df3["Timestamp"] = pd.to_datetime(df3['Timestamp'], errors='coerce')
df3 =  df3[df3['Timestamp'] >= '2023-07-01']

# %%
df3.head()
# Out:
#                                                   Name           Timestamp  \
# 564                                             Claire 2023-07-06 10:47:19
# 565  Love and Cornbread (Bombas socks) (data entry ... 2023-07-11 14:03:04
# 566                                             Claire 2023-07-12 09:36:53
# 567                                             Claire 2023-07-12 13:17:16
# 568                                             Claire 2023-07-14 15:11:41
#
#      Weight Rack Number: Where is the food coming from?   \
# 564  40,000           Xx                            Dole
# 565    1512           xx              Love and Cornbread
# 566     205           Xx                  Dietz & Watson
# 567   36720           Xx             Farmlink [Mauricio]
# 568   27236           Xx              Clemens Food Group
#
#     What category of product   Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 564         Dole - Fruit cups         NaN         NaN         NaN        NaN
# ...

# %%
df3.columns
# Out:
# Index(['Name', 'Timestamp', 'Weight', 'Rack Number:',
#        'Where is the food coming from? ', 'What category of product ',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
df3['What category of product '] = df3['What category of product '].replace('Clothing', 'Personal Care')
df3['What category of product '] = df3['What category of product '].replace('Pickles', 'Produce')
df3['What category of product '] = df3['What category of product '].replace('Drinks (Dry)', 'Drinks [Dry]')
df3['What category of product '] = df3['What category of product '].replace('Drinks (Fridge)', 'Drinks [Fridge]')
df3['What category of product '] = df3['What category of product '].replace('Mixed Fridge ', 'Assorted Fridge')
df3['What category of product '] = df3['What category of product '].replace(np.nan, 'Other')
df3['What category of product '] = df3['What category of product '].replace("Baby Formula", 'Baby Supplies')
df3['What category of product '] = df3['What category of product '].replace("Bags, assortment", 'Paper Supplies')
df3['What category of product '] = df3['What category of product '].replace("Bags, assorted", 'Paper Supplies')
df3['What category of product '] = df3['What category of product '].replace("Mixed", 'Assorted Dry')
df3['What category of product '] = df3['What category of product '].replace("Sweet and sour mix", 'Other')
df3['What category of product '] = df3['What category of product '].replace("Pineapple mix", 'Other')
df3['What category of product '] = df3['What category of product '].replace("Pineapple bites", 'Produce')
df3['What category of product '] = df3['What category of product '].replace("Replenish ", 'Other')
df3['What category of product '] = df3['What category of product '].replace("Bread", 'Grains (rice, pasta, etc.)')
df3['What category of product '] = df3['What category of product '].replace("Beans", 'Canned Goods')
df3['What category of product '] = df3['What category of product '].replace("Spices", 'Condiments')
df3['What category of product '] = df3['What category of product '].replace("socks", 'Personal Care')
df3['What category of product '] = df3['What category of product '].replace("SOCKS", 'Personal Care')
df3['What category of product '] = df3['What category of product '].replace("cheese", 'Dairy')
df3['What category of product '] = df3['What category of product '].replace("Chips/cereal", 'Grains (rice, pasta, etc.)')
df3['What category of product '] = df3['What category of product '].replace("Can Produce", 'Produce')
df3['What category of product '] = df3['What category of product '].replace("bread", 'Grains (rice, pasta, etc.)')

# %%
df3['What category of product '].unique()
# Out:
# array(['Dole - Fruit cups', 'Personal Care', 'Meat [Raw]', 'Produce',
#        'Assorted Dry', 'Assorted Fridge', 'Frozen [Not Meat]',
#        'Drinks [Dry]', 'Snacks', 'Other', 'Drinks [Fridge]',
#        'Canned Goods', 'Baby Supplies', 'Paper Supplies',
#        'Health & Beauty Products', 'Cleaning Supplies', 'Danone - Milk',
#        'Pet Supplies', 'Grains (rice, pasta, etc.)', 'Condiments',
#        'Water', 'Household', 'Dairy', 'Can Produce ', 'Danone - Creamer'],
#       dtype=object)

# %%
df3['Where is the food coming from? '] = df3['Where is the food coming from? '].str.strip()
df3['Where is the food coming from? '] = df3['Where is the food coming from? '].replace("MEANS", 'MEANS DATABASE')
df3['Where is the food coming from? '] = df3['Where is the food coming from? '].replace('Donation, Girls in the Game', 'Girls in the Game')
df3['Where is the food coming from? '] = df3['Where is the food coming from? '].replace('GIRLS IN THE GAME', 'Girls in the Game')
df3['Where is the food coming from? '] = df3['Where is the food coming from? '].replace(np.nan, 'Other')
df3['Where is the food coming from? '] = df3['Where is the food coming from? '].replace('bombas', 'Bombas')
df3['Where is the food coming from? '] = df3['Where is the food coming from? '].replace('BOMBAS', 'Bombas')
df3['Where is the food coming from? '] = df3['Where is the food coming from? '].replace('Neighbors', 'Neighbor')
df3['Where is the food coming from? '] = df3['Where is the food coming from? '].replace('Homewood', 'Homewood Friends Meeting')
df3['Where is the food coming from? '] = df3['Where is the food coming from? '].replace('minute made', 'Minute Made')
df3['Where is the food coming from? '] = df3['Where is the food coming from? '].replace('Minute Maid', 'Minute Made')

# %%
df3['Where is the food coming from? '].unique()
# Out:
# array(['Dole', 'Love and Cornbread', 'Dietz & Watson',
#        'Farmlink [Mauricio]', 'Clemens Food Group', 'Amazon',
#        'Donation [Baltimore Youth Arts]', 'MEANS DATABASE',
#        'Girls in the Game', 'First Fruits Farm', 'Home with Friends',
#        'Other', 'EMD', 'Dean Chem', 'Quakers', 'BCF',
#        'South Baltimore community gardens', 'South Baltimore',
#        'Bmore Harm Reduction', 'Lush', 'Homewood Friends Meeting',
#        'Quaker', 'Chloe foster donation', 'Sandtown (Quaker)',
#        'Saint James episcopal church food outreach', 'Bmore Table',
#        'Neighbor', 'Baltimore orchard project', 'Walmart', 'Bombas',
#        'The Cat Scale Company', 'Minute Made', 'Chewys.com', 'apo',
#        'Arce', 'Jack and Sudznos', 'Lineage'], dtype=object)

# %%
df3['Name'] = df3['Name'].str.strip()
df3["Name"] = df3["Name"].replace('M. Safire Windley', 'Safire Windley')
df3["Name"] = df3["Name"].replace('Robin Gibbs/St Ambrose Catholic Church/Oblate Sisters', 'Robin Gibbs')
df3["Name"] = df3["Name"].replace('Robin Gibbs/St Ambrose Church/ Oblate Sisters', 'Robin Gibbs')
df3["Name"] = df3["Name"].replace('Safire W', 'Safire Windley')
df3["Name"] = df3["Name"].replace('Barb Zadek', 'Barbara Zadek')
df3["Name"] = df3["Name"].replace('Pedro (8/5)', 'Pedro')
df3["Name"] = df3["Name"].replace('Arce (8/6)', 'Janet Arce')
df3["Name"] = df3["Name"].replace('St.Ambrose Mother House', 'Robin Gibbs')
df3["Name"] = df3["Name"].replace('Nina', 'Nina Early')
df3["Name"] = df3["Name"].replace('SAFIRE W', 'Safire Windley')
df3["Name"] = df3["Name"].replace('SAFIRE', 'Safire Windley')
df3["Name"] = df3["Name"].replace('Sunita', 'Sunita Pathik')
df3["Name"] = df3["Name"].replace('Sunita pathik', 'Sunita Pathik')
df3["Name"] = df3["Name"].replace(np.nan, 'Other')
df3["Name"] = df3["Name"].replace('lorissa m', 'Lorissa M')
df3["Name"] = df3["Name"].replace('Aaron Oldenburg 8/19/23', 'Aaron Oldenburg')
df3["Name"] = df3["Name"].replace('Arce', 'Janet Arce')
df3["Name"] = df3["Name"].replace('Beverly Pinnn', 'Beverly Pinn')
df3["Name"] = df3["Name"].replace('Peter campbell', 'Peter Campbell')
df3["Name"] = df3["Name"].replace('Kingdom Worship center', 'Kingdom Worship Center')
df3["Name"] = df3["Name"].replace('Kingdom worship center', 'Kingdom Worship Center')
df3["Name"] = df3["Name"].replace('Chi chi', 'Chi Chi')
df3["Name"] = df3["Name"].replace('Xinyue gu', 'Xinyue Gu')
df3["Name"] = df3["Name"].replace('XinyuebGu', 'Xinyue Gu')
df3["Name"] = df3["Name"].replace('Xinyue', 'Xinyue Gu')
df3["Name"] = df3["Name"].replace('XX', 'Other')
df3["Name"] = df3["Name"].replace('chi    9/9/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi    9/28/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi   9/28/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi      9/28/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi      9/29/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('Haven for the Homeless - Bria Evans', 'Bria Evans')
df3["Name"] = df3["Name"].replace('chi    9/8/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi chi', 'Chi Chi')
df3["Name"] = df3["Name"].replace('CHI CHI', 'Chi Chi')
df3["Name"] = df3["Name"].replace('Chi', 'Chi Chi')
df3["Name"] = df3["Name"].replace('Aaron Oldenburg 10/14/23', 'Aaron Oldenburg')
df3["Name"] = df3["Name"].replace('Aaron Oldenburg 10/13/23', 'Aaron Oldenburg')
df3["Name"] = df3["Name"].replace('Crustal shaw', 'Crystal Shaw')
df3["Name"] = df3["Name"].replace('Crystal shaw', 'Crystal Shaw')
df3["Name"] = df3["Name"].replace('CHI', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi', 'Chi Chi')
df3["Name"] = df3["Name"].replace('marci', 'Marci')
df3["Name"] = df3["Name"].replace('Nathaniel', 'Nathaniel Sheps')
df3["Name"] = df3["Name"].replace('Eve', 'Evelyn')
df3["Name"] = df3["Name"].replace('Eve', 'Evelyn')
df3["Name"] = df3["Name"].replace('Love and Cornbread (Bombas socks) (data entry Anna W)', 'Anna W')
df3["Name"] = df3["Name"].replace('M Safire windley', 'Safire Windley')
df3["Name"] = df3["Name"].replace('Aaron Oldenburg 8/11/23', 'Aaron Oldenburg')
df3["Name"] = df3["Name"].replace('SAFIRE WINDLEY', 'Safire Windley')
df3["Name"] = df3["Name"].replace('Msafirewindley', 'Safire Windley')
df3["Name"] = df3["Name"].replace('M.Safire Windley', 'Safire Windley')
df3["Name"] = df3["Name"].replace('Msafire Windley', 'Safire Windley')
df3["Name"] = df3["Name"].replace('Windley', 'Safire Windley')
df3["Name"] = df3["Name"].replace('Sara B', 'Sara B.')
df3["Name"] = df3["Name"].replace('Sara.', 'Sara B.')
df3["Name"] = df3["Name"].replace('Waldo Álvarez', 'Waldo Alvarez')
df3["Name"] = df3["Name"].replace('Waldo Alvare', 'Waldo Alvarez')
df3["Name"] = df3["Name"].replace('Anne from Bmore Table', 'Anne')
df3["Name"] = df3["Name"].replace('chi-chi 9/27/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi-chi', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi  9/27/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi   9/27/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi     9/27/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi    9/27/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi  9/9/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('chi   9/9/23', 'Chi Chi')
df3["Name"] = df3["Name"].replace('Ann/Homewoid Friends', 'Ann Walker Kennedy')
df3["Name"] = df3["Name"].replace('Sunny Choi (Not a repeat)', 'Sunny Choi')
df3["Name"] = df3["Name"].replace('Marci', 'Marci Yankelov')
df3["Name"] = df3["Name"].replace('Rochelle', 'Rochelle Clunie')
df3["Name"] = df3["Name"].replace('Rochelle Clunie (Old Entry for 12.11.23)', 'Rochelle Clunie')

# %%
df3["Name"].unique()
# Out:
# array(['Claire', 'Anna W', 'Safire Windley', 'Robin Gibbs', 'JC', 'Peter',
#        'Amazon', 'Other', 'Aaron Oldenburg', 'Beverly Pinn', 'Chi Chi',
#        'Liz Simon-Higgs', 'Beverly Pi.', 'Ronald Robinson',
#        'Ann Walker Kennedy', 'Bryant Martin', 'Sara B.', 'Karen',
#        'Michelle Collins', 'Chloe Foster', 'Denise Rivers',
#        'Waldo Alvarez', 'Kate', 'Anne', 'Rochelle Clunie', 'Sunny Choi',
#        'Marci Yankelov', 'Christina', 'Jahmal Johnson',
#        'Homewood friends meeting'], dtype=object)

# %%
df3.columns
# Out:
# Index(['Name', 'Timestamp', 'Weight', 'Rack Number:',
#        'Where is the food coming from? ', 'What category of product ',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
print('[')
for i, row in df3.iterrows():
    print('\t{')
    print('\t\tdate: ' + '"' + str(row['Timestamp']) + '"' + ',')
    print('\t\tname: ' + '"'+ string.capwords(row['Name']) + '"' +',')
    print('\t\tweight: ' + str(row['Weight']) + ',')
    print('\t\tcategory: ' + '"'+ string.capwords(row['What category of product ']) + '"' +',')
    print('\t\tdistributor: ' + '"'+ string.capwords(row['Where is the food coming from? '])+ '"')
    print('\t},')
print(']')

# %%
df4 = pd.read_csv("volunteer.csv")
df4["Timestamp"] = pd.to_datetime(df4['Timestamp'], errors='coerce')
df4 =  df4[df4['Timestamp'] >= '2023-07-01']

# %%
df4.head()
# Out:
#                Timestamp                Name What category of food?  \
# 294  2023-12-28 00:00:00  Jade Weatherington   Damage/expired/extra
# 297  2023-12-28 00:00:00           Azel King   Damage/expired/extra
# 1319 2023-07-11 15:18:10    Romaine Bouldin   Regular (up to 20lbs)
# 1320 2023-07-11 15:18:41     Beverly Graham   Regular (up to 20lbs)
# 1321 2023-07-11 15:19:15      Edward Benner   Regular (up to 20lbs)
#
#      Weight (Numbers only!)  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 294                       4         NaN         NaN         NaN
# 297                       5         NaN         NaN         NaN
# 1319                     10         NaN         NaN         NaN
# 1320                      7         NaN         NaN         NaN
# 1321                     20         NaN         NaN         NaN

# %%
df4.columns
# Out:
# Index(['Timestamp', 'Name', 'What category of food?', 'Weight (Numbers only!)',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
df4['Weight (Numbers only!)'] = df4['Weight (Numbers only!)'].replace(np.nan, '0')
df4['Weight (Numbers only!)'] = df4['Weight (Numbers only!)'].replace('3 lb', '3')
df4['Weight (Numbers only!)'] = df4['Weight (Numbers only!)'].replace('9 lb', '9')

# %%
df4['Weight (Numbers only!)'].unique()
# Out:
# array(['4', '5', '10', '7', '20', '6', '133', '48', '41', '109', '18',
#        '0', '13', '16', '12', '9', '30', '35', '19', '14', '32', '36',
#        '8', '15', '17', '22', '74', '11', '31', '46', '57', '1', '2', '3',
#        '40', '21', '39', '23', '25', '34', '26', '84', '56', '110', '160',
#        '50', '27'], dtype=object)

# %%
df4['What category of food?'] = df4['What category of food?'].replace(np.nan, 'Regular (up to 20lbs)')
df4['What category of food?'] = df4['What category of food?'].replace('regular (up to 20lbs)', 'Regular (up to 20lbs)')

# %%
df4['What category of food?'].unique()
# Out:
# array(['Damage/expired/extra', 'Regular (up to 20lbs)'], dtype=object)

# %%
df4['Name'] = df4['Name'].str.strip()
df4["Name"] = df4["Name"].replace('Luke mayhew', 'Luke Mayhew')
df4["Name"] = df4["Name"].replace('Marci', 'Marci Yankelov')
df4["Name"] = df4["Name"].replace('Sara B.', 'Sara Brown')
df4["Name"] = df4["Name"].replace('nathan', 'Nathan')
df4["Name"] = df4["Name"].replace('marci Yankelov', 'Marci Yankelov')
df4["Name"] = df4["Name"].replace('Sunita pathik', 'Sunita Pathik')
df4["Name"] = df4["Name"].replace('Kate weeks', 'Kate Weeks')
df4["Name"] = df4["Name"].replace('Breyonna pittman', 'Breyonna Pittman')
df4["Name"] = df4["Name"].replace('Bud Stracker+DPW drinks', 'Bud Stracker')
df4["Name"] = df4["Name"].replace('Bud Stracker - sisson st dpw drinks', 'Bud Stracker')
df4["Name"] = df4["Name"].replace('Sara B', 'Sara Brown')
df4["Name"] = df4["Name"].replace('Myra McDonskd', 'Myra McDonald')
df4["Name"] = df4["Name"].replace('Tyree Reka vinson', 'Tyree Reka Vinson')
df4["Name"] = df4["Name"].replace('Tyree vinson', 'Tyree Reka Vinson')
df4["Name"] = df4["Name"].replace('anton woronczuk', 'Anton Woronczuk')
df4["Name"] = df4["Name"].replace('Waldo', 'Waldo Alvarez')
df4["Name"] = df4["Name"].replace('Bud Stracker-sisson st dpw drinks', 'Bud Stracker')
df4["Name"] = df4["Name"].replace('Eli kengmana', 'Eli Kengmana')
df4["Name"] = df4["Name"].replace('Veronica Mcdonald', 'Veronica McDonald')
df4["Name"] = df4["Name"].replace('Eyitayo  Enitan', 'Eyitayo Enitan')
df4["Name"] = df4["Name"].replace('anisa hamilton', 'Anisa Hamilton')
df4["Name"] = df4["Name"].replace('Van gullivan', 'Van Gullivan')
df4["Name"] = df4["Name"].replace('adeola sulaiman', 'Adeola Sulaiman')
df4["Name"] = df4["Name"].replace('0', 'Other')
df4["Name"] = df4["Name"].replace('marci', 'Marci Yankelov')
df4["Name"] = df4["Name"].replace('Lauren crouch', 'Lauren Crouch')
df4["Name"] = df4["Name"].replace('Nana alesia richards', 'Nana Alesia Richards')
df4["Name"] = df4["Name"].replace('anisa', 'Anisa Hamilton')
df4["Name"] = df4["Name"].replace('ally hickman', 'Ally Hickman')
df4["Name"] = df4["Name"].replace('Deborah cousin', 'Deborah Cousin')
df4["Name"] = df4["Name"].replace('Terell little', 'Terell Little')
df4["Name"] = df4["Name"].replace('Elena porras', 'Elena Porras')
df4["Name"] = df4["Name"].replace('Anyway carter', 'Anyway Carter')
df4["Name"] = df4["Name"].replace('Lauren  Crouch 18 pou and', 'Lauren  Crouch')
df4["Name"] = df4["Name"].replace('Wyatt', 'Wyatt Ray')
df4["Name"] = df4["Name"].replace('Wyatt ray', 'Wyatt Ray')
df4["Name"] = df4["Name"].replace('marcie yankelov', 'Marci Yankelov')
df4["Name"] = df4["Name"].replace('wylder voegele', 'Wylder Voegele')
df4["Name"] = df4["Name"].replace('Wylder voegele', 'Wylder Voegele')
df4["Name"] = df4["Name"].replace('Nate McClean', 'Nate McClean')
df4["Name"] = df4["Name"].replace('aziza frsnk', 'Aziza Frank')
df4["Name"] = df4["Name"].replace('aziza frank', 'Aziza Frank')
df4["Name"] = df4["Name"].replace('aziza', 'Aziza Frank')
df4["Name"] = df4["Name"].replace('Aziza', 'Aziza Frank')

# %%
df4["Name"].unique()
# Out:
# array(['Jade Weatherington', 'Azel King', 'Romaine Bouldin',
#        'Beverly Graham', 'Edward Benner', 'Anna West', 'Karen',
#        'Luke Mayhew', 'Phillip Gatling', 'Kytica Crawford',
#        'Obinna Nwokoro', 'Marci Yankelov', 'Sharon Johndon', 'Sarah K',
#        'Ryan Murphy', 'Robin Gibbs', 'Alex', 'Scott Fox',
#        'Aaron Oldenburg', 'Sara', 'Sara Brown', 'Tram Nguyen',
#        'Ajay Macherla', 'Emily Fitzpatrick', 'Breyonna Pittman', 'Nathan',
#        'Tiffany Jiang', 'Demain Dacosta', 'Tatiana Bowman',
#        'Aaliyiah Moye-Tati', 'Rabia Chaudhry', 'Shannon Householder',
#        'Brenda Ames', 'Michelle Collins', 'Sunita Pathik', 'Ryan',
#        'Calvin Bethea', 'Bernard McDonald', 'Emily Stucke',
#        'Emily Engelbrecht-Wiggins', 'Kate Weeks', 'Johanna Galat',
#        'Kevin James', 'Zoe', 'Christopher Royston', 'Nevaeh Christy',
#        'Temiloluwa Osunjimi', 'Bud Stracker', 'Beverly Pinn',
# ...

# %%
df4.columns
# Out:
# Index(['Timestamp', 'Name', 'What category of food?', 'Weight (Numbers only!)',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
df4['What category of food?'].unique()
# Out:
# array(['Damage/expired/extra', 'Regular (up to 20lbs)'], dtype=object)

# %%
print('[')
for i, row in df4.iterrows():
    print('\t{')
    print('\t\tstart: ' + '"' + str(row['Timestamp']) + '"' + ',')
    print('\t\tend: ' + '"'+ str(row['Timestamp']) + '"' +',')
    print('\t\tname: ' + '"'+ string.capwords(row['Name']) + '"' +',')
    if row['What category of food?'] == 'Damage/expired/extra':
        print('\t\tregularTaken: ' + str(0) + ',',)
        print('\t\tregularTaken: ' + str(row['Weight (Numbers only!)']) + ',',)
    else:
        print('\t\tregularTaken: ' + str(row['Weight (Numbers only!)']) + ',',)
        print('\t\tregularTaken: ' + str(0) + ',',)
    print('\t},')
print(']')
